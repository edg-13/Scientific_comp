# %%
import matplotlib as mpl
#mpl.use("nbagg")
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Example 1

# %% [markdown]
# ## No damping
# # $x(t) = x_0 + v_{x,0} t$
# # $y(t) = y_0 + v_{y,0} t - \frac{1}{2}g t^2$

# %% [markdown]
# ## with damping
# # $ x(t) = x_0 + \frac{1-\exp(-\frac{\gamma}{m} t)}{\gamma}m v_{x,0} $
# # $ y(t) = y_0 + \frac{1-\exp(-\frac{\gamma}{m} t)}{\gamma}m v_{y,0} -\frac{m}{\gamma}g m t + \frac{1-\exp(-\frac{\gamma}{m} t)}{\gamma^2}m^2 g$

# %%
# x0 = 0.0
# y0 = 0.0
# vx0 = 10.0
# vy0 = 0.0
# gamma = 2.0
# dt = 0.01


x0 = 10.0
y0 = 10.0
vx0 = 1.25
vy0 = 5.75
gamma = 2.0
dt = 1.0

with open("/Users/albert/Google Drive/PX390_Week4_LE/le4_1_input.txt","w") as f:
    f.write("{} {} {} {} {} {}".format(x0,y0,vx0,vy0,gamma,dt))

# %%
out = np.loadtxt("/Users/albert/Google Drive/PX390_Week4_LE/output.dat")

t = out[:,0]
m = 1.0
g = 9.80665

if gamma > 0.0:
    my_x = x0 + (1 - np.exp(-gamma*t/m))*m*vx0/gamma
    my_y = -( np.exp(-gamma*t/m) - 1 )*g*m**2/gamma**2 + y0 - g*m*t/gamma + (1 - np.exp(-gamma*t/m))*m*vy0/gamma 
else:
    my_x = x0+vx0*t
    my_y = y0+vy0*t-0.5*g*t**2

# %%
plt.plot(t,out[:,1])
plt.plot(t,my_x,"--")
plt.xlabel("time (s)")
plt.ylabel("x (m)")
plt.show()

plt.plot(t,out[:,1]-my_x)
plt.xlabel("time (s)")
plt.ylabel("error in x (m)")
plt.show()

plt.semilogy(t,np.abs(out[:,1]-my_x))
plt.xlabel("time (s)")
plt.ylabel("absolute error in x (m)")
plt.show()

plt.plot(t,out[:,2])
plt.plot(t,my_y,"--")
plt.xlabel("time (s)")
plt.ylabel("y (m)")
plt.show()

plt.plot(t,out[:,2]-my_y)
plt.xlabel("time (s)")
plt.ylabel("error in y (m)")
plt.show()

plt.semilogy(t,np.abs(out[:,2]-my_y))
plt.xlabel("time (s)")
plt.ylabel("absolute error in y (m)")
plt.show()
# Out:
# /Users/albert/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """Entry point for launching an IPython kernel.
# <img src="data:image/png;base64,..." width="640">
# /Users/albert/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:7: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   import sys
# <img src="data:image/png;base64,..." width="640">
# ...

# %% [markdown]
# # Example 2

# %% [markdown]
# # $\frac{\mathrm{d}y}{\mathrm{d}x} = \gamma y$
# # $y(x) = y_0 \exp( \gamma x )$

# %%
out = np.loadtxt("/Users/albert/Google Drive/PX390_Week4_LE/output_2.dat")

# %%
t = out[:,0]

y0 = 1.0
gamma = -4.0
my_y = y0*np.exp(gamma*t)

# %%
plt.plot(t,out[:,1])
plt.plot(t,my_y,"--")
plt.xlabel("time (s)")
plt.ylabel("y (a.u.)")
plt.show()

plt.plot(t,out[:,1]-my_y)
plt.xlabel("time (s)")
plt.ylabel("error in y (a.u.)")
plt.show()

plt.semilogy(t,np.abs(out[:,1]-my_y))
plt.xlabel("time (s)")
plt.ylabel("absolute error in y (a.u.)")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Example 2 modified

# %%
y0 = 1.0
gamma = -4.0
dt = 0.5

with open("/Users/albert/Google Drive/PX390_Week4_LE/le4_2_input.txt","w") as f:
    f.write("{} {} {}".format(y0,gamma,dt))

# %%
out = np.loadtxt("/Users/albert/Google Drive/PX390_Week4_LE/output_2.dat")
t = out[:,0]

my_y = y0*np.exp(gamma*t)

# %%
plt.plot(t,out[:,1])
plt.plot(t,my_y,"--")
plt.xlabel("time (s)")
plt.ylabel("y (a.u.)")
plt.show()

plt.plot(t,out[:,1]-my_y)
plt.xlabel("time (s)")
plt.ylabel("error in y (a.u.)")
plt.show()

plt.semilogy(t,np.abs(out[:,1]-my_y))
plt.xlabel("time (s)")
plt.ylabel("absolute error in y (a.u.)")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# /Users/albert/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   if sys.path[0] == '':
# <img src="data:image/png;base64,..." width="640">
